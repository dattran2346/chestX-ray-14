# %%
import pandas as pd

# %%
df = pd.read_csv('backup_test.csv')
df
# Out:
#                      Model  Atelectasis  Cardiomegaly  Effusion  Infiltration  \
# 0              Wang et al.     0.716000      0.807000  0.784000      0.609000
# 1               Yao et al.     0.772000      0.904000  0.859000      0.695000
# 2                  CheXNet     0.809400      0.924800  0.863800      0.734500
# 3  Our Implemented CheXNet     0.829400      0.916500  0.887000      0.714300
# 4       Our Improved Model     0.831100      0.922000  0.889100      0.714600
# 5                Microsoft     0.828543      0.891449  0.817697      0.907302
#
#        Mass    Nodule  Pneumonia  Pneumothorax  Consolidation     Edema  \
# 0  0.706000  0.670100   0.633000      0.806000       0.708000  0.835000
# 1  0.792000  0.717000   0.713000      0.841000       0.788000  0.882000
# 2  0.867600  0.780200   0.768000      0.888700       0.790100  0.887800
# 3  0.859700  0.787300   0.774500      0.872600       0.814200  0.893200
# ...

# %%
df['Mean'] = df.iloc[:, 1:].mean(axis=1)
df
# Out:
#                      Model  Atelectasis  Cardiomegaly  Effusion  Infiltration  \
# 0              Wang et al.     0.716000      0.807000  0.784000      0.609000
# 1               Yao et al.     0.772000      0.904000  0.859000      0.695000
# 2                  CheXNet     0.809400      0.924800  0.863800      0.734500
# 3  Our Implemented CheXNet     0.829400      0.916500  0.887000      0.714300
# 4       Our Improved Model     0.831100      0.922000  0.889100      0.714600
# 5                Microsoft     0.828543      0.891449  0.817697      0.907302
#
#        Mass    Nodule  Pneumonia  Pneumothorax  Consolidation     Edema  \
# 0  0.706000  0.670100   0.633000      0.806000       0.708000  0.835000
# 1  0.792000  0.717000   0.713000      0.841000       0.788000  0.882000
# 2  0.867600  0.780200   0.768000      0.888700       0.790100  0.887800
# 3  0.859700  0.787300   0.774500      0.872600       0.814200  0.893200
# ...

# %%
df.to_csv('test.csv', index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-510f660eda84> in <module>()
# ----> 1 df.to_csv('test.csv', index=None)
#
# NameError: name 'df' is not defined

# %%
test_df = pd.read_csv('test.csv')
idx = test_df.Model.apply(lambda r: r in ['Wang et al.', 'Yao et al.', 'CheXNet', 'Microsoft', 'Our Improved Model', '20180430-162711'])

extract_df = test_df[idx].T
extract_df.to_csv('extract.csv', header=None)
extract_df
# Out:
#                              0           1         2                   4   \
# Model               Wang et al.  Yao et al.   CheXNet  Our Improved Model
# Atelectasis               0.716       0.772    0.8094              0.8311
# Cardiomegaly              0.807       0.904    0.9248               0.922
# Effusion                  0.784       0.859    0.8638              0.8891
# Infiltration              0.609       0.695    0.7345              0.7146
# Mass                      0.706       0.792    0.8676              0.8627
# Nodule                   0.6701       0.717    0.7802              0.7883
# Pneumonia                 0.633       0.713     0.768               0.782
# Pneumothorax              0.806       0.841    0.8887              0.8844
# Consolidation             0.708       0.788    0.7901              0.8148
# Edema                     0.835       0.882    0.8878              0.8992
# Emphysema                 0.815       0.829    0.9371              0.9343
# ...
