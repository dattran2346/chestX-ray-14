# %%
import pandas as pd

# %%
df = pd.read_csv('backup_test.csv')
df
# Out:
#                      Model  Atelectasis  Cardiomegaly  Effusion  Infiltration  \
# 0              Wang et al.     0.716000      0.807000  0.784000      0.609000
# 1               Yao et al.     0.772000      0.904000  0.859000      0.695000
# 2                  CheXNet     0.809400      0.924800  0.863800      0.734500
# 3  Our Implemented CheXNet     0.829400      0.916500  0.887000      0.714300
# 4       Our Improved Model     0.831100      0.922000  0.889100      0.714600
# 5                Microsoft     0.828543      0.891449  0.817697      0.907302
#
#        Mass    Nodule  Pneumonia  Pneumothorax  Consolidation     Edema  \
# 0  0.706000  0.670100   0.633000      0.806000       0.708000  0.835000
# 1  0.792000  0.717000   0.713000      0.841000       0.788000  0.882000
# 2  0.867600  0.780200   0.768000      0.888700       0.790100  0.887800
# 3  0.859700  0.787300   0.774500      0.872600       0.814200  0.893200
# ...

# %%
df['Mean'] = df.iloc[:, 1:].mean(axis=1)
df
# Out:
#                      Model  Atelectasis  Cardiomegaly  Effusion  Infiltration  \
# 0              Wang et al.     0.716000      0.807000  0.784000      0.609000
# 1               Yao et al.     0.772000      0.904000  0.859000      0.695000
# 2                  CheXNet     0.809400      0.924800  0.863800      0.734500
# 3  Our Implemented CheXNet     0.829400      0.916500  0.887000      0.714300
# 4       Our Improved Model     0.831100      0.922000  0.889100      0.714600
# 5                Microsoft     0.828543      0.891449  0.817697      0.907302
#
#        Mass    Nodule  Pneumonia  Pneumothorax  Consolidation     Edema  \
# 0  0.706000  0.670100   0.633000      0.806000       0.708000  0.835000
# 1  0.792000  0.717000   0.713000      0.841000       0.788000  0.882000
# 2  0.867600  0.780200   0.768000      0.888700       0.790100  0.887800
# 3  0.859700  0.787300   0.774500      0.872600       0.814200  0.893200
# ...

# %%
df.to_csv('test.csv', index=None)
